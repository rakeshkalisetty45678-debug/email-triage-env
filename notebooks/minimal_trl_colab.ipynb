# %% [markdown]
# # Executive Assistant Negotiation Env: Minimal TRL Colab
#
# This notebook installs the environment, runs a quick benchmark, and launches a minimal GRPO training loop that scores completions by replaying them inside the OpenEnv environment.

# %%
# !pip install -q openenv-core>=0.2.3 fastapi uvicorn pydantic pillow datasets transformers accelerate trl peft torch

# %%
# !git clone https://github.com/rakeshkalisetty45678-debug/email-triage-env.git repo
# %cd repo

# %%
# !python scripts/benchmark.py

# %%
# !python scripts/train_sft_submission.py
# !python scripts/plot_training_state.py
# !python scripts/evaluate_submission.py
